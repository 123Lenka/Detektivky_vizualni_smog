# %%
import pandas as pd

addresses = pd.read_csv('combined_addresses_cz_cleaned.csv')

addresses
# Out:
#          adm_code  city_code                city           city_part  \
# 0        15770460     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 1        15770478     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 2        15770486     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 3        15770494     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 4        15770508     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# ...           ...        ...                 ...                 ...
# 3001227  79245790     563625    Haškovcova Lhota    Haškovcova Lhota
# 3001228  81615671     563625    Haškovcova Lhota    Haškovcova Lhota
# 3001229  81655177     563625    Haškovcova Lhota    Haškovcova Lhota
# 3001230  85347931     563625    Haškovcova Lhota    Haškovcova Lhota
# 3001231  85881562     563625    Haškovcova Lhota    Haškovcova Lhota
#
#          city_part_code street  building_number  orientation_number  \
# 0                 89273    NaN                1                 NaN
# ...

# %%
city_info = addresses[(addresses["postal_code"] == 37006) & (addresses["city"] == "České Budějovice")]

#& (addresses["city"] == "Jenišov")]
# & (addresses["street"] == "Jaroslava Kociána")]
#& (addresses["building_number"] == 1360)]
#(addresses["postal_code"] == 53345)
#(addresses["city_code"] == 545066)
city_info
# Out:
#          adm_code  city_code              city           city_part  \
# 2485356  23384654     544256  České Budějovice  České Budějovice 4
# 2485404  23385154     544256  České Budějovice  České Budějovice 5
# 2485405  23385162     544256  České Budějovice  České Budějovice 5
# 2485406  23385171     544256  České Budějovice  České Budějovice 5
# 2485407  23385189     544256  České Budějovice  České Budějovice 5
# ...           ...        ...               ...                 ...
# 2494160  86475215     544256  České Budějovice  České Budějovice 5
# 2494161  86475274     544256  České Budějovice  České Budějovice 5
# 2494162  86475410     544256  České Budějovice  České Budějovice 5
# 2494164  86535277     544256  České Budějovice  České Budějovice 5
# 2494190  86856138     544256  České Budějovice  České Budějovice 5
#
#          city_part_code            street  building_number  \
# 2485356          403890          Vrbenská              481
# ...
