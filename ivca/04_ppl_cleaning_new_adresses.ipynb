# %%
import pandas as pd

df = pd.read_csv('unikatni_ppl_vse.csv')

df.head(5)
# Out:
#     id2       id accessPointType  pickupEnabled               lastChange  \
# 0  1458  4561221       ParcelBox           True  2025-05-03T09:54:52,960
# 1   349  4540715       ParcelBox           True  2025-05-04T16:14:36,117
# 2  1453  4561215       ParcelBox           True  2025-05-04T10:14:51,537
# 3  1768  4573395       ParcelBox           True  2025-04-30T19:35:25,280
# 4   965  4328610       ParcelBox           True  2025-05-03T17:12:51,560
#
#                                 name capacityStatus   latitude  longitude  \
# 0              PBOX ACE Míru (U CBA)           Free  50.162559  17.573313
# 1       PBOX ACE Středová (ADRIATOM)           Free  49.783430  18.522770
# 2         PBOX ADV Nádražní (Albert)           Free  49.300471  16.651568
# 3  PBOX ANV Albrechtice n.V (Vachta)           Free  49.256399  14.307878
# 4         PBOX ASH Chebská (IQ Wash)           Free  50.213569  12.199983
#
#   box_type city_abbr           street      note                      slouceny  \
# ...

# %%
new_df = df['address'].str.split(',', expand=True)

# %%
new_df.head(5)
# Out:
#                             0  \
# 0                   Míru 12/3
# 1                Středová 408
# 2                      Albert
# 3  Albrechtice nad Vltavou 16
# 4                Chebská 2934
#
#                                                   1                        2  \
# 0                          793 95 Město Albrechtice                  Czechia
# 1   735 43 Albrechtice-Albrechtice u Českého Těšína                  Czechia
# 2                                       Nádražní 42   679 04 Adamov-Adamov 1
# 3                    398 16 Albrechtice nad Vltavou                  Czechia
# 4                                    352 01 Aš-Aš 1                  Czechia
#
#           3     4
# 0      None  None
# 1      None  None
# 2   Czechia  None
# 3      None  None
# 4      None  None

# %%
new_df.to_csv('ppl_adresy.csv', index=False, encoding='utf-8')

# %%
df.to_csv('unikatni_ppl_pokus2.csv', index=False, encoding='utf-8')
