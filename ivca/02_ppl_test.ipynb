# %%
import pandas as pd

df = pd.read_csv('data_ppl_box_clean.csv')

df.head(5)
# Out:
#         id accessPointType  pickupEnabled               lastChange  \
# 0  4441996       ParcelBox           True   2025-05-04T15:53:50.88
# 1  4442021       ParcelBox           True    2025-05-04T10:13:46.9
# 2  4445468       ParcelBox           True  2025-05-04T14:33:51.737
# 3  4445470       ParcelBox           True  2025-05-04T16:13:55.477
# 4  4447573       ParcelBox           True  2025-05-04T12:34:00.763
#
#                                 name capacityStatus   latitude  longitude  \
# 0         PBOX HVV Dlouhá třída (OC)           Free  49.775506  18.450683
# 1       PBOX ZNS Bratří Čapků (Bala)           Free  49.563189  15.946509
# 2         PBOX DME Mánesova (Družba)           Free  49.445367  12.927450
# 3  PBOX BOR Nám.republiky (Potravin)           Free  49.712540  12.773685
# 4        PBOX BRN Kroupova (Nonstop)           Free  49.165532  16.561897
#
#   box_type city_abbr         street      note
# 0     PBOX       HVV   Dlouhá třída        OC
# ...

# %%
df["slouceny"] = '"' + df["latitude"].astype(str) + ',' + df["longitude"].astype(str) + '",'

df.head(5)
# Out:
#         id accessPointType  pickupEnabled               lastChange  \
# 0  4441996       ParcelBox           True   2025-05-04T15:53:50.88
# 1  4442021       ParcelBox           True    2025-05-04T10:13:46.9
# 2  4445468       ParcelBox           True  2025-05-04T14:33:51.737
# 3  4445470       ParcelBox           True  2025-05-04T16:13:55.477
# 4  4447573       ParcelBox           True  2025-05-04T12:34:00.763
#
#                                 name capacityStatus   latitude  longitude  \
# 0         PBOX HVV Dlouhá třída (OC)           Free  49.775506  18.450683
# 1       PBOX ZNS Bratří Čapků (Bala)           Free  49.563189  15.946509
# 2         PBOX DME Mánesova (Družba)           Free  49.445367  12.927450
# 3  PBOX BOR Nám.republiky (Potravin)           Free  49.712540  12.773685
# 4        PBOX BRN Kroupova (Nonstop)           Free  49.165532  16.561897
#
#   box_type city_abbr         street      note                      slouceny
# ...

# %%
df.to_csv('test_ppl_vse.csv', index=False, encoding='utf-8')
