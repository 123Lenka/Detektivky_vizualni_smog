# %%
import pandas as pd

addresses = pd.read_csv('combined_addresses_cz_cleaned.csv')

addresses.head(3)
# Out:
#    adm_codeadm_code  city_code                city           city_part  \
# 0          15770460     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 1          15770478     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
# 2          15770486     570362  Lužec nad Cidlinou  Lužec nad Cidlinou
#
#    city_part_code street  building_number  orientation_number  postal_code  \
# 0           89273    NaN                1                 NaN        50362
# 1           89273    NaN                2                 NaN        50362
# 2           89273    NaN                3                 NaN        50362
#
#     latitude   longitude           valid_from
# 0  670380.71  1038460.11  2013-12-05T00:00:00
# 1  670460.38  1038386.31  2013-12-05T00:00:00
# 2  670502.86  1038386.88  2022-10-30T00:00:00

# %%
city_info = addresses[
    # addresses['city'].str.contains('Brno', case=False, na=False) 
    # &
    (addresses['city_code'] == 553549)
    # &
    # addresses['postal_code'].astype(str).str.contains('73802', case=False, na=False)
    &
    addresses['building_number'].astype(str).str.contains('55', case=False, na=False)
]
city_info
# Out:
#          adm_codeadm_code  city_code          city      city_part  \
# 2301930           6747884     553549  Česká Kubice   Česká Kubice
# 2302176          27328261     553549  Česká Kubice  Horní Folmava
# 2302245          82031894     553549  Česká Kubice   Česká Kubice
#
#          city_part_code street  building_number  orientation_number  \
# 2301930           21369    NaN               55                 NaN
# 2302176           34568    NaN               55                 NaN
# 2302245           21369    NaN              155                 NaN
#
#          postal_code   latitude   longitude           valid_from
# 2301930        34532  865919.25  1105670.38  2013-12-05T00:00:00
# 2302176        34532  866891.80  1107835.45  2013-12-05T00:00:00
# 2302245        34532  865804.96  1105270.31  2021-08-17T00:00:00

# %%
city_info = addresses[(addresses['city_code'] == 598003)]

city_info
# Out:
#          adm_codeadm_code  city_code           city city_part  city_part_code  \
# 1139258          20420889     598003  Frýdek-Místek    Frýdek           34991
# 1139259          20420901     598003  Frýdek-Místek    Frýdek           34991
# 1139260          20420951     598003  Frýdek-Místek    Frýdek           34991
# 1139261          20420960     598003  Frýdek-Místek    Frýdek           34991
# 1139262          20420978     598003  Frýdek-Místek    Frýdek           34991
# ...                   ...        ...            ...       ...             ...
# 1146496          86834118     598003  Frýdek-Místek    Místek          413119
# 1146497          86864246     598003  Frýdek-Místek    Frýdek           34991
# 1146498          86883216     598003  Frýdek-Místek   Skalice          147974
# 1146499          86918923     598003  Frýdek-Místek    Místek          413119
# 1146500          86919024     598003  Frýdek-Místek    Místek          413119
#
# ...
